# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pytz

import preprocess as prep

# %% [markdown]
# # load data set

# %% [markdown]
# ## load training set

# %%
train = pd.read_csv("../../input/train.csv")
train["count"] = 1
train["train_test"] = "train"
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#  ## load test set

# %%
test = pd.read_csv("../../input/test.csv")
test["count"] = 1
test["train_test"] = "test"
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# ## data

# %%
print("train:\n",train.dtypes,"\n")
# Out:
# train:
#  Pclass        category
# Sex           category
# alone         category
# Embarked      category
# title         category
# last_name     category
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket_len       int64
# Fare           float64
# Cabin_len        int64
# relatives        int64
# Survived         Int64
# dtype: object

# %%
print("test:\n",test.dtypes,"\n")
# Out:
# test:
#  Pclass         category
# Sex            category
# alone          category
# Embarked       category
# title          category
# last_name      category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket_len        int64
# Fare            float64
# Cabin_len         int64
# relatives         int64
# PassengerId       int64
# dtype: object

# %%
def current_timestamp():
    EST_ZONE = pytz.timezone("America/New_York") 
    CURRENT_TIME_EST = datetime.now(EST_ZONE)
    current_timestamp = CURRENT_TIME_EST.strftime("%Y%m%d-%H%M%S")
    return current_timestamp

# %%
feature_list = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket_len', 'Fare', 'Cabin_len', 'Embarked', 'title', 'last_name', 'relatives', 'alone']
categorical = ['Pclass', 'Sex', 'alone', 'Embarked', 'title', 'last_name']
continuous = ['Age', 'SibSp', 'Parch', 'Ticket_len', 'Fare', 'Cabin_len', 'relatives']
target = "Survived"
PassengerId="PassengerId"

# %%
tr_te = pd.concat([train, test], sort=False)
tr_te
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
feature_list_training = categorical + continuous

train, test = prep.preprocess(tr_te, feature_list_training, target, PassengerId)
display(train)
display(test)
# Out:
# 'title' feature is created
# 'relative' feature is created
# 'alone' feature is created
# 'Ticket_len' feature is created
# dtype of Pclass has been changed to category
# dtype of Sex has been changed to category
# dtype of Cabin has been changed to category
# dtype of Embarked has been changed to category
# dtype of last_name has been changed to category
# dtype of title has been changed to category
# dtype of alone has been changed to category
# dtype of Survived has been changed to int
#
#
#  print dtypes
# Pclass        category
# Sex           category
# alone         category
# Embarked      category
# title         category
# last_name     category
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket_len       int64
# Fare           float64
# Cabin_len        int64
# relatives        int64
# Survived         Int64
# dtype: object
#     Pclass     Sex alone Embarked  title  last_name        Age  SibSp  Parch  \
# ...

# %% [markdown]
# ## pipeline for preprocessing

# %%
#ddd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score

# %%
transformer_num = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]
)

transformer_cate = Pipeline(
#    steps=[("encoder", OneHotEncoder(handle_unknown="ignore"))]
    steps=[("encoder", TargetEncoder())]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", transformer_num, continuous),
        ("cat", transformer_cate, categorical),
    ]
)

# %%
def xgboost_bayes_opt(learning_rate, n_estimators, max_depth, gamma):
    max_depth = int(max_depth)
    n_estimators = int(n_estimators)
    clf = Pipeline(
        steps=[("preprocessor", preprocessor), 
            ("classifier", XGBClassifier(
                learning_rate = learning_rate,
                n_estimators = n_estimators,
                max_depth = max_depth,
                gamma = gamma,
                eval_metric='aucpr',
                random_state = 42,
                enable_categorical=True,               
            ))]
    )
    return np.mean(cross_val_score(clf, train[feature_list], y=train[target], cv=5, scoring='accuracy'))

# %%
pbounds = {
    'learning_rate': (0.01, 1.0),
    'n_estimators': (10, 500),
    'max_depth': (3,7),
#    'subsample': (1.0, 1.0),  # Change for big datasets
#    'colsample': (1.0, 1.0),  # Change for datasets with lots of features
    'gamma': (0, 5)}

optimizer = BayesianOptimization(
    f = xgboost_bayes_opt,
    pbounds = pbounds,
    random_state = 42
)

# %%
optimizer.maximize(init_points=20, n_iter=4)
# Out:
# |   iter    |  target   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------
# | 1         | 0.835     | 1.873     | 0.9512    | 5.928     | 303.3     |
# | 2         | 0.8406    | 0.7801    | 0.1644    | 3.232     | 434.4     |
# | 3         | 0.8373    | 3.006     | 0.711     | 3.082     | 485.3     |
# | 4         | 0.8361    | 4.162     | 0.2202    | 3.727     | 99.87     |
# | 5         | 0.8395    | 1.521     | 0.5295    | 4.728     | 152.7     |
# | 6         | 0.8361    | 3.059     | 0.1481    | 4.169     | 189.5     |
# | 7         | 0.8361    | 2.28      | 0.7873    | 3.799     | 262.0     |
# | 8         | 0.8395    | 2.962     | 0.05599   | 5.43      | 93.56     |
# | 9         | 0.8182    | 0.3253    | 0.9494    | 6.863     | 406.1     |
# | 10        | 0.835     | 1.523     | 0.1067    | 5.737     | 225.7     |
# | 11        | 0.835     | 0.6102    | 0.5002    | 3.138     | 455.6     |
# ...

# %%
print("Best result: {}; f(x) = {}.".format(optimizer.max["params"], optimizer.max["target"]))
# Out:
# Best result: {'gamma': np.float64(0.4424625102595975), 'learning_rate': np.float64(0.20402303379495376), 'max_depth': np.float64(3.1809091556421523), 'n_estimators': np.float64(169.41186207399952)}; f(x) = 0.8462368966166594.

# %%
best_param = optimizer.max["params"]
best_param["max_depth"] = int(best_param["max_depth"])
best_param["n_estimators"] = int(best_param["n_estimators"])
best_param
# Out:
# {'gamma': np.float64(0.4424625102595975),
#  'learning_rate': np.float64(0.20402303379495376),
#  'max_depth': 3,
#  'n_estimators': 169}

# %%
model_XGB = Pipeline(
    steps=[("preprocessor", preprocessor), 
        ("classifier", XGBClassifier(
            **best_param,
            eval_metric='aucpr',
            random_state = 42,
            enable_categorical=True,               
        ))]
)
model_XGB.fit(train[feature_list],train[target])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'SibSp', 'Parch',
#                                                    'Ticket_len', 'Fare',
#                                                    'Cabin_len', 'relatives']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    TargetEncoder())]),
#                                                   ['Pclass', 'Sex', 'alone',
# ...

# %%
res_tb = test[["PassengerId"]]
res_tb["Survived"] = model_XGB.predict(test[feature_list])
res_tb
# Out:
# C:\Users\sungh\AppData\Local\Temp\ipykernel_3464\2010437532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_tb["Survived"] = model_XGB.predict(test[feature_list])
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
current_ts = current_timestamp()
res_tb.to_csv(f"../../output/res_xgb_TargetEncoder_{current_ts}.csv",index=False)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
def logistic_bayes_opt(C):
    clf = Pipeline(
        steps=[("preprocessor", preprocessor), 
            ("classifier", LogisticRegression(C = C, random_state = 42)
            )]
    )
    return np.mean(cross_val_score(clf, train[feature_list], y=train[target], cv=5, scoring='accuracy'))

# %%
pbounds = {"C": [0.1, 10]}
optimizer = BayesianOptimization(
    f = logistic_bayes_opt,
    pbounds = pbounds,
    random_state = 42
)

# %%
optimizer.maximize(init_points=20, n_iter=4)
# Out:
# |   iter    |  target   |     C     |
# -------------------------------------
# | 1         | 0.826     | 3.808     |
# | 2         | 0.8204    | 9.512     |
# | 3         | 0.8294    | 7.347     |
# | 4         | 0.8272    | 6.027     |
# | 5         | 0.8204    | 1.645     |
# | 6         | 0.826     | 1.644     |
# | 7         | 0.8182    | 0.675     |
# | 8         | 0.8305    | 8.675     |
# | 9         | 0.8215    | 6.051     |
# | 10        | 0.8294    | 7.11      |
# | 11        | 0.8148    | 0.3038    |
# | 12        | 0.8227    | 9.702     |
# | 13        | 0.8316    | 8.341     |
# | 14        | 0.8227    | 2.202     |
# | 15        | 0.8238    | 1.9       |
# | 16        | 0.8249    | 1.916     |
# | 17        | 0.8238    | 3.112     |
# | 18        | 0.8272    | 5.295     |
# | 19        | 0.8249    | 4.376     |
# | 20        | 0.8227    | 2.983     |
# | 21        | 0.826     | 3.808     |
# | 22        | 0.8271    | 8.341     |
# | 23        | 0.8283    | 8.342     |
# ...

# %%
print("Best result: {}; f(x) = {}.".format(optimizer.max["params"], optimizer.max["target"]))
# Out:
# Best result: {'C': np.float64(7.347093400428152)}; f(x) = 0.8327663046889713.

# %%
best_param = optimizer.max["params"]
best_param
# Out:
# {'C': np.float64(7.347093400428152)}

# %%
model_logistic = Pipeline(
    steps=[("preprocessor", preprocessor), 
        ("classifier", LogisticRegression(**best_param, random_state = 42)
        )]
)
model_logistic.fit(train[feature_list],train[target])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'SibSp', 'Parch',
#                                                    'Ticket_len', 'Fare',
#                                                    'Cabin_len', 'relatives']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    TargetEncoder())]),
#                                                   ['Pclass', 'Sex', 'alone',
# ...

# %%
res_tb = test[["PassengerId"]]
res_tb["Survived"] = model_logistic.predict(test[feature_list]).astype(int)
res_tb
# Out:
# C:\Users\sungh\AppData\Local\Temp\ipykernel_3464\435265536.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_tb["Survived"] = model_logistic.predict(test[feature_list]).astype(int)
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
current_ts = current_timestamp()
res_tb.to_csv(f"../../output/res_logistic_TargetEncoder{current_ts}.csv",index=False)
