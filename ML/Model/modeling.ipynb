# %% [markdown]
# # import packages

# %%
import pandas as pd
# import numpy as np
# from datetime import datetime
# import pytz
import model
import preprocess as prep

# %% [markdown]
# # load data set (training & test)

# %% [markdown]
# ## load training set

# %%
train = pd.read_csv("../../input/train.csv")
train["count"] = 1
train["train_test"] = "train"
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#  ## load test set

# %%
test = pd.read_csv("../../input/test.csv")
test["count"] = 1
test["train_test"] = "test"
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # data preprocessing

# %%
print("train:\n",train.dtypes,"\n")
# Out:
# train:
#  PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# count            int64
# train_test      object
# dtype: object

# %%
print("test:\n",test.dtypes,"\n")
# Out:
# test:
#  PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# count            int64
# train_test      object
# dtype: object

# %%
## features to use for modeling
feature_list = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket_len', 'Fare', 'Cabin_len', 'Embarked', 'title', 'last_name', 'relatives', 'alone']
categorical = ['Pclass', 'Sex', 'alone', 'Embarked', 'title', 'last_name']
continuous = ['Age', 'SibSp', 'Parch', 'Ticket_len', 'Fare', 'Cabin_len', 'relatives']
target = "Survived"
PassengerId="PassengerId"

# %% [markdown]
# ## concat training and test dataset for preprocessing.

# %%
tr_te = pd.concat([train, test], sort=False)
tr_te
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
feature_list_training = categorical + continuous
feature_list_train = feature_list + [target]
feature_list_test = feature_list + [PassengerId]

df = prep.preprocess(tr_te)

train = df.loc[df["train_test"]=="train",feature_list_train]
test = df.loc[df["train_test"]=="test",feature_list_test]

X_train = train[feature_list]
y_train = train[target]
X_test = test[feature_list]

display(train)
display(test)
# Out:
# 'title' feature is created
# 'relative' feature is created
# 'alone' feature is created
# 'Ticket_len' feature is created
# dtype of Pclass has been changed to category
# dtype of Sex has been changed to category
# dtype of Cabin has been changed to category
# dtype of Embarked has been changed to category
# dtype of last_name has been changed to category
# dtype of title has been changed to category
# dtype of alone has been changed to category
# dtype of Survived has been changed to int
#     Pclass     Sex        Age  SibSp  Parch  Ticket_len     Fare  Cabin_len  \
# 0        3    male  22.000000      1      0           9   7.2500          7
# 1        1  female  38.000000      1      0           8  71.2833          3
# 2        3  female  26.000000      0      0          16   7.9250          7
# 3        1  female  35.000000      1      0           6  53.1000          4
# 4        3    male  35.000000      0      0           6   8.0500          7
# ...

# %% [markdown]
# ## pipeline for preprocessing

# %%
preprocessor = model.pipeline_preprocess(continuous, categorical)
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Age', 'SibSp', 'Parch', 'Ticket_len', 'Fare',
#                                   'Cabin_len', 'relatives']),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder', TargetEncoder())]),
#                                  ['Pclass', 'Sex', 'alone', 'Embarked', 'title',
#                                   'last_name'])])

# %% [markdown]
# # model1 : XGBOOST

# %% [markdown]
# ## Bayesian Optimazation to find best hyperparameter for xgboost

# %%
pbounds_xgb = {
    'learning_rate': (0.01, 1.0),
    'n_estimators': (10, 500),
    'max_depth': (3,7),
    'gamma': (0, 5)}

best_param_xgb = model.bayesian_opt_xgboost(X_train, y_train, pbounds_xgb, preprocessor)
# Out:
# |   iter    |  target   |   gamma   | learni... | max_depth | n_esti... |
# -------------------------------------------------------------------------
# | 1         | 0.8384    | 1.873     | 0.9512    | 5.928     | 303.3     |
# | 2         | 0.8362    | 0.7801    | 0.1644    | 3.232     | 434.4     |
# | 3         | 0.8239    | 3.006     | 0.711     | 3.082     | 485.3     |
# | 4         | 0.8227    | 4.162     | 0.2202    | 3.727     | 99.87     |
# | 5         | 0.8451    | 1.521     | 0.5295    | 4.728     | 152.7     |
# | 6         | 0.8417    | 3.059     | 0.1481    | 4.169     | 189.5     |
# | 7         | 0.844     | 2.28      | 0.7873    | 3.799     | 262.0     |
# | 8         | 0.8339    | 2.962     | 0.05599   | 5.43      | 93.56     |
# | 9         | 0.8215    | 0.3253    | 0.9494    | 6.863     | 406.1     |
# | 10        | 0.8362    | 1.523     | 0.1067    | 5.737     | 225.7     |
# | 11        | 0.8361    | 0.6102    | 0.5002    | 3.138     | 455.6     |
# ...

# %% [markdown]
# ## fit and predict using xgboost with best hyperparameter.

# %%
res_tb_xgb = test[["PassengerId"]]
res_tb_xgb["Survived"] = model.xgb_fit_and_predict(preprocessor, best_param_xgb, X_train, y_train, X_test)
res_tb_xgb
# Out:
# C:\Users\sungh\AppData\Local\Temp\ipykernel_13884\2678080151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_tb_xgb["Survived"] = model.xgb_fit_and_predict(preprocessor, best_param_xgb, X_train, y_train, X_test)
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
current_ts = model.current_timestamp()
res_tb_xgb.to_csv(f"../../output/res_xgb_TargetEncoder_{current_ts}.csv",index=False)

# %% [markdown]
# # model2 : Logistic Regression

# %% [markdown]
# ## Bayesian Optimazation to find best hyperparameter for Logistic Regression

# %%
pbounds_lr = {"C": [0.1, 10]}

best_param_lr = model.bayesian_opt_logisticRegression(X_train, y_train, pbounds_lr, preprocessor)
# Out:
# |   iter    |  target   |     C     |
# -------------------------------------
# | 1         | 0.8249    | 3.808     |
# | 2         | 0.8294    | 9.512     |
# | 3         | 0.8283    | 7.347     |
# | 4         | 0.8249    | 6.027     |
# | 5         | 0.8249    | 1.645     |
# | 6         | 0.8238    | 1.644     |
# | 7         | 0.8182    | 0.675     |
# | 8         | 0.8215    | 8.675     |
# | 9         | 0.826     | 6.051     |
# | 10        | 0.8339    | 7.11      |
# | 11        | 0.8181    | 0.3038    |
# | 12        | 0.8283    | 9.702     |
# | 13        | 0.8294    | 8.341     |
# | 14        | 0.826     | 2.202     |
# | 15        | 0.8249    | 1.9       |
# | 16        | 0.8215    | 1.916     |
# | 17        | 0.826     | 3.112     |
# | 18        | 0.826     | 5.295     |
# | 19        | 0.8272    | 4.376     |
# | 20        | 0.826     | 2.983     |
# | 21        | 0.8215    | 7.111     |
# | 22        | 0.826     | 7.11      |
# | 23        | 0.8227    | 4.376     |
# ...

# %% [markdown]
# ## fit and predict using Logistic Regression with best hyperparameter.

# %%
res_tb_lr = test[["PassengerId"]]
res_tb_lr["Survived"] = model.logisticRegression_fit_and_predict(preprocessor, best_param_lr, X_train, y_train, X_test).astype(int)
res_tb_lr
# Out:
# C:\Users\sungh\AppData\Local\Temp\ipykernel_13884\648943519.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_tb_lr["Survived"] = model.logisticRegression_fit_and_predict(preprocessor, best_param_lr, X_train, y_train, X_test).astype(int)
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
current_ts = model.current_timestamp()
res_tb_lr.to_csv(f"../../output/res_logistic_TargetEncoder{current_ts}.csv",index=False)
